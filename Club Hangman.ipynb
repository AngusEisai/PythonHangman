# %%
# List of random words 
# Select word from random words list 
# Count how many characters are in the word
# Display blanks for every letter in the word 
# User inputs a letter, if letter is correct the blank in that letters place in the word is replaced by the letter. 
# If the letter is incorrect the, the blank remains and a line is drawn on a blank page
# Repeat up to 10 times, when all 10 hang man lines are drawn, game ends. 
# 
# If the letter is correct and is repeated multiple times in the chosen word, all blanks in place of that letter are replaced with the letter.

# %%
import pandas as pd

# %%
wordlist = pd.read_table("C:\\Users\eel21382\\OneDrive - Eisai\\My Documents\Python Club\\Tools\\wordlist.txt")

# %%
words = (list)

# %%
with open("C:\\Users\eel21382\\OneDrive - Eisai\\My Documents\Python Club\\Tools\\wordlist.txt") as f:
    words = f.readlines()
    print (words)
# Out:
# ['aardvark\n', 'aardwolf\n', 'aaron\n', 'aback\n', 'abacus\n', 'abaft\n', 'abalone\n', 'abandon\n', 'abandoned\n', 'abandonment\n', 'abandons\n', 'abase\n', 'abased\n', 'abasement\n', 'abash\n', 'abashed\n', 'abate\n', 'abated\n', 'abatement\n', 'abates\n', 'abattoir\n', 'abattoirs\n', 'abbe\n', 'abbess\n', 'abbey\n', 'abbeys\n', 'abbot\n', 'abbots\n', 'abbreviate\n', 'abbreviated\n', 'abbreviates\n', 'abbreviating\n', 'abbreviation\n', 'abbreviations\n', 'abdicate\n', 'abdicated\n', 'abdicates\n', 'abdicating\n', 'abdication\n', 'abdomen\n', 'abdomens\n', 'abdominal\n', 'abduct\n', 'abducted\n', 'abducting\n', 'abduction\n', 'abductions\n', 'abductor\n', 'abductors\n', 'abducts\n', 'abe\n', 'abeam\n', 'abel\n', 'abele\n', 'aberdeen\n', 'aberrant\n', 'aberration\n', 'aberrations\n', 'abet\n', 'abets\n', 'abetted\n', 'abetting\n', 'abeyance\n', 'abhor\n', 'abhorred\n', 'abhorrence\n', 'abhorrent\n', 'abhors\n', 'abide\n', 'abided\n', 'abides\n', 'abiding\n', 'abidjan\n', 'abies\n', 'a
# ...

# %%
words2 = []

for i in words:
    words2.append(i.strip())
print(words2)
# Out:
# ['aardvark', 'aardwolf', 'aaron', 'aback', 'abacus', 'abaft', 'abalone', 'abandon', 'abandoned', 'abandonment', 'abandons', 'abase', 'abased', 'abasement', 'abash', 'abashed', 'abate', 'abated', 'abatement', 'abates', 'abattoir', 'abattoirs', 'abbe', 'abbess', 'abbey', 'abbeys', 'abbot', 'abbots', 'abbreviate', 'abbreviated', 'abbreviates', 'abbreviating', 'abbreviation', 'abbreviations', 'abdicate', 'abdicated', 'abdicates', 'abdicating', 'abdication', 'abdomen', 'abdomens', 'abdominal', 'abduct', 'abducted', 'abducting', 'abduction', 'abductions', 'abductor', 'abductors', 'abducts', 'abe', 'abeam', 'abel', 'abele', 'aberdeen', 'aberrant', 'aberration', 'aberrations', 'abet', 'abets', 'abetted', 'abetting', 'abeyance', 'abhor', 'abhorred', 'abhorrence', 'abhorrent', 'abhors', 'abide', 'abided', 'abides', 'abiding', 'abidjan', 'abies', 'abilities', 'ability', 'abject', 'abjectly', 'abjure', 'abjured', 'ablate', 'ablates', 'ablating', 'ablation', 'ablative', 'ablaze', 'able', 'ablebod
# ...

# %%
import random

hangman = random.choice(words2)

print(hangman)
# Out:
# rotating

# %%
len(hangman)
# Out:
# 8

# %%
lines=list(len(hangman)*'_')
print(lines)
# Out:
# ['_', '_', '_', '_', '_', '_', '_', '_']

# %%
print("m" in hangman)
# Out:
# False

# %%
letter = input("Pick a letter")
if letter in hangman:
    print(letter,end='')
else:
    print('_',end = ' ')
# Out:
# Make a guesst
# t

# %% [markdown]
# 1. Search word for letter
# 2. If letter is present, replace line with letter
# 3. If letter is not present display part of hangman
# 4. Repeat

# %%
hangman.index(letter)
# Out:
# 2

# %%
lines[hangman.index(letter)]=letter

# %%
print(lines)
# Out:
# ['_', '_', 't', 'a', '_', '_', '_', '_']
